# %%
import numpy as np
import pandas as pd

# %%
# Melakukan import dataset
df = pd.read_csv('CarpriceIndia.csv')
df
# Out:
#         ID                              Name    Location  Year  \
# 0        1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1        2                      Honda Jazz V     Chennai  2011
# 2        3                 Maruti Ertiga VDI     Chennai  2012
# 3        4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4        6            Nissan Micra Diesel XV      Jaipur  2013
# ...    ...                               ...         ...   ...
# 5948  6014                  Maruti Swift VDI       Delhi  2014
# 5949  6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5950  6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5951  6017                Maruti Wagon R VXI     Kolkata  2013
# 5952  6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission  Engine_CC  Power_bhp  Price
# 0                 41000    Diesel       Manual     1582.0     126.20  12.50
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# Menggunakan kolom ID menjadi kolom index
df.set_index('ID', inplace=True)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
# Memeriksa tipe data dari setiap kolom dalam dataset
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Engine_CC            float64
# Power_bhp            float64
# Price                float64
# dtype: object

# %%
# Memperoleh ringkasan informasi mengenai dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5953 entries, 1 to 6018
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5953 non-null   object
#  1   Location           5953 non-null   object
#  2   Year               5953 non-null   int64
#  3   Kilometers_Driven  5953 non-null   int64
#  4   Fuel_Type          5953 non-null   object
#  5   Transmission       5953 non-null   object
#  6   Engine_CC          5917 non-null   float64
#  7   Power_bhp          5811 non-null   float64
#  8   Price              5953 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 465.1+ KB

# %%
# Menjelaskan fungsi dari setiap kolom
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# A lakh is a unit in the Indian numbering system equal to one hundred thousand (100,000)
#
# Sumber: https://en.wikipedia.org/wiki/Lakh

# %%
## Memeriksa Data Duplikat
df.duplicated().sum()
# Out:
# 1

# %%
# Melakukan akses baris data yang terindikasi duplikat
print(df[df.duplicated(keep=False)])
# Out:
#              Name   Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# ID
# 369   BMW X5 3.0d  Bangalore  2009              90000    Diesel    Automatic
# 2993  BMW X5 3.0d  Bangalore  2009              90000    Diesel    Automatic
#
#       Engine_CC  Power_bhp  Price
# ID
# 369      2993.0      235.0  17.75
# 2993     2993.0      235.0  17.75

# %% [markdown]
# Terdapat data duplikat namun terdapat asumsi bahwa adanya dua kendaraan yang memiliki ciri - ciri yang sama persis

# %%
# Memeriksa pada kolom apa saja yang terdapat missing value pada dataset
df.isna().any(axis=0)
# Out:
# Name                 False
# Location             False
# Year                 False
# Kilometers_Driven    False
# Fuel_Type            False
# Transmission         False
# Engine_CC             True
# Power_bhp             True
# Price                False
# dtype: bool

# %% [markdown]
# Terdapat 2 kolom yang memiliki nilai null atau missing value

# %%
# Mencetak seluruh baris data yang terdapat Missing Value pada kolom *Engine_CC*
CC_null = pd.isnull(df['Engine_CC'])
df[CC_null]
# Out:
#                                               Name    Location  Year  \
# ID
# 194                             Honda City 1.5 GXI   Ahmedabad  2007
# 208                           Maruti Swift 1.3 VXi     Kolkata  2010
# 733                           Maruti Swift 1.3 VXi     Chennai  2006
# 749                   Land Rover Range Rover 3.0 D      Mumbai  2008
# 1294                             Honda City 1.3 DX       Delhi  2009
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad  2015
# 1385                            Honda City 1.5 GXI        Pune  2004
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  2008
# 2074                          Maruti Swift 1.3 LXI        Pune  2011
# 2096                     Hyundai Santro LP zipPlus  Coimbatore  2004
# 2264                           Toyota Etios Liva V        Pune  2012
# 2325                      Maruti Swift 1.3 VXI ABS        Pune  2015
# ...

# %% [markdown]
# ## Mengatasi Missing Value

# %%
# Melakukan input untuk mengisi missing value sesuai dengan index nya
df['Engine_CC'].loc[194] = 1493
df['Engine_CC'].loc[208] = 1298
df['Engine_CC'].loc[733] = 1298 
df['Engine_CC'].loc[749] = 2993
df['Engine_CC'].loc[1294] = 1298 
df['Engine_CC'].loc[1327] = 1198
df['Engine_CC'].loc[1385] = 1493 
df['Engine_CC'].loc[1460] = 2993 
df['Engine_CC'].loc[2074] = 1198
df['Engine_CC'].loc[2096] = 1086
df['Engine_CC'].loc[2264] = 1197
df['Engine_CC'].loc[2325] = 1198
df['Engine_CC'].loc[2335] = 1198
df['Engine_CC'].loc[2530] = 1995
df['Engine_CC'].loc[2542] = 1086

df['Engine_CC'].loc[2623] = 1995 
df['Engine_CC'].loc[2668] = 1198 
df['Engine_CC'].loc[2737] = 998 
df['Engine_CC'].loc[2780] = 1086 
df['Engine_CC'].loc[2842] = 1086 
df['Engine_CC'].loc[3272] = 1995 
df['Engine_CC'].loc[3404] = 1198 
df['Engine_CC'].loc[3520] = 1995

df['Engine_CC'].loc[3522] = 1086 
df['Engine_CC'].loc[3810] = 2354 
df['Engine_CC'].loc[4011] = 1248 
df['Engine_CC'].loc[4152] = 2993 
df['Engine_CC'].loc[4229] = 1086 
df['Engine_CC'].loc[4577] = 1995
df['Engine_CC'].loc[4604] = 1199 
df['Engine_CC'].loc[4697] = 1248 
df['Engine_CC'].loc[4712] = 1086 
df['Engine_CC'].loc[4952] = 1172 
df['Engine_CC'].loc[5015] = 1198 
df['Engine_CC'].loc[5185] = 1198 
df['Engine_CC'].loc[5270] = 1493
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_11824\2993334767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Engine_CC'].loc[194] = 1493
# C:\Users\adity\AppData\Local\Temp\ipykernel_11824\2993334767.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Engine_CC'].loc[208] = 1298
# C:\Users\adity\AppData\Local\Temp\ipykernel_11824\2993334767.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ![Screenshot_1.png](attachment:857a0095-5aee-4e2b-a3ac-9f68be1a1311.png)
#
# Sumber : https://www.cardekho.com/overview/Maruti_Swift_2004-2011/Maruti_Swift_2004-2011_VXI_BSIII.htm

# %% [markdown]
# ## Missing Value ```Engine_CC```

# %%
# Melakukan validasi apakah missing value pada kolom Engine_CC telah terisi
CC_null = pd.isnull(df['Engine_CC'])
df[CC_null]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Engine_CC, Power_bhp, Price]
# Index: []

# %%
df.loc[208]
# Out:
# Name                 Maruti Swift 1.3 VXi
# Location                          Kolkata
# Year                                 2010
# Kilometers_Driven                   42001
# Fuel_Type                          Petrol
# Transmission                       Manual
# Engine_CC                          1298.0
# Power_bhp                             NaN
# Price                                2.11
# Name: 208, dtype: object

# %% [markdown]
# ## Missing Value ```Power_BHP```

# %% [markdown]
# **Individuals purchasing a vehicle pay the road tax which is based on the ex-showroom price of the vehicle. The calculation of road tax depends on these following things:**
# 1. Seating capacity of the vehicle
# 2. Engine capacity of the vehicle
# 3. Age of the vehicle
# 4. Weight of the Vehicle
#
# Sumber: https://www.bankbazaar.com/driving-licence/rules-regulations-of-road-tax-india.html

# %% [markdown]
# Maka diputuskan bahwa kolom 'Power_bhp' dapat dihapus karena tidak adanya dampak kolom tersebut dalam pengambilan keputusan dan mengurangi kolom yang perlu diisi oleh pengurus kedepannya

# %%
# Melakukan penghapusan kolom Power_bhp yang disebabkan oleh tidak adanya dampak kolom tersebut dalam pengambilan keputusan
df.drop('Power_bhp',axis =1, inplace = False)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission  Engine_CC  Price
# ID
# ...

# %% [markdown]
# ## Memeriksa Outlier

# %%
# Membuat def fungsi untuk melakukan cek ada nya outlier dalam setiap kolom
def Cek_Outliers(df, col):
    q1 = df[col].describe()['25%']
    q3 = df[col].describe()['75%']
    iqr = q3 - q1
    upper_fence = q3 + (1.5*iqr)
    lower_fence = q1 - (1.5*iqr)
    df_outliers = df[(df[col] < lower_fence) | (df[col] > upper_fence)]
    if len(df_outliers) == 0:
        return "No Outliers"
    else:
        return df_outliers

# %%
# Cek Outliers Year
df_outliers_year = Cek_Outliers(df,'Year')
df_outliers_year
# Out:
#                                       Name   Location  Year  \
# ID
# 274                    Maruti Zen VXI BSII     Mumbai  2002
# 315                        Tata Sumo Delux  Hyderabad  2000
# 364                          Maruti Zen LX    Kolkata  2003
# 613              Mahindra Bolero ZLX BSIII    Kolkata  2000
# 631              Hyundai Santro LS zipPlus    Chennai  2002
# 911                    Maruti Zen VXI BSII      Kochi  2003
# 1221        Ambassador Classic Nova Diesel    Chennai  2003
# 1224                         Maruti Zen VX     Jaipur  1999
# 1318                    Honda City 1.3 EXI  Ahmedabad  2002
# 1845                    Honda City 1.3 EXI       Pune  1999
# 1903      Skoda Octavia Classic 1.9 TDI MT    Kolkata  2002
# 1907                   Toyota Qualis FS B3  Bangalore  2002
# 1999         Mercedes-Benz E-Class 220 CDI       Pune  2001
# 2487                     Toyota Corolla DX    Chennai  2003
# 2524              Maruti Wagon R VXI BSIII    Chennai  2003
# ...

# %%
# Mencetak baris data dengan nilai tahun terkecil dalam dataframe outliers
df_outliers_year['Year'].min()
# Out:
# 1998

# %%
# Mencetak baris data dengan nilai tahun terbesar dalam dataframe outliers
df_outliers_year['Year'].max()
# Out:
# 2003

# %%
# Melakukan crosstab untuk mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan usia masing - masing kendaraan
pd.crosstab(index = df['Age'], columns = 'Jumlah Kendaraan',
            values = df['Name'], aggfunc='count',
           colnames= [''])
# Out:
#      Jumlah Kendaraan
# Age
# 3                 101
# 4                 294
# 5                 582
# 6                 737
# 7                 735
# 8                 785
# 9                 640
# 10                569
# 11                464
# 12                337
# 13                198
# 14                172
# 15                124
# 16                 78
# 17                 56
# 18                 31
# 19                 17
# 20                 15
# 21                  8
# 22                  4
# 23                  2
# 24                  4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Mencetak diagram kotak garis dengan 'Year' sebagai sumbu x nya
sns.boxplot(data=df, x='Year')
plt.show()

# %% [markdown]
# Data pada kolom *Year* yang termasuk dalam outlier merupakan kendaraan yang berusia sangat tua (19 - 24 Tahun)

# %%
# Cek Outlier Price
df_outliers_price = Cek_Outliers(df,'Price')
df_outliers_price
# Out:
#                                                   Name   Location  Year  \
# ID
# 13                    Land Rover Range Rover 2.2L Pure      Delhi  2014
# 19    Mercedes-Benz New C-Class C 220 CDI BE Avantgare  Bangalore  2014
# 22                Audi A6 2011-2015 35 TFSI Technology     Mumbai  2015
# 38                    Mercedes-Benz M-Class ML 350 CDI       Pune  2013
# 50                Audi A4 2.0 TDI 177 Bhp Premium Plus      Kochi  2015
# ...                                                ...        ...   ...
# 5946               BMW 5 Series 2013-2017 530d M Sport  Bangalore  2016
# 5950                                   Audi Q3 2.0 TDI  Bangalore  2014
# 5970                 Mercedes-Benz GLA Class 200 Sport      Kochi  2018
# 5996                        Jaguar XF 2.2 Litre Luxury      Kochi  2016
# 6008                           Porsche Panamera Diesel  Hyderabad  2013
#
#       Kilometers_Driven Fuel_Type Transmission  Engine_CC  Power_bhp  Price  \
# ID
# ...

# %%
# Mencetak baris data kendaraan dengan harga terendah pada outliers
df_outliers_price.min()
# Out:
# Name                 Audi A3 35 TDI Technology
# Location                             Ahmedabad
# Year                                      2006
# Kilometers_Driven                         1000
# Fuel_Type                               Diesel
# Transmission                         Automatic
# Engine_CC                               1395.0
# Power_bhp                                107.3
# Price                                     19.8
# Age                                          3
# dtype: object

# %%
# Mencetak baris data kendaraan dengan harga tertinggi pada outliers
df_outliers_price.max()
# Out:
# Name                 Volvo XC90 2007-2015 D5 AWD
# Location                                    Pune
# Year                                        2019
# Kilometers_Driven                        6500000
# Fuel_Type                                 Petrol
# Transmission                              Manual
# Engine_CC                                 5998.0
# Power_bhp                                  560.0
# Price                                      160.0
# Age                                           16
# dtype: object

# %%
# Mencetak diagram kotak garis dengan 'Price' sebagai sumbu x nya
sns.boxplot(data=df, x='Price')
plt.show()

# %% [markdown]
# Data pada kolom *Price* yang termasuk dalam outlier merupakan kendaraan yang memiliki harga yang terbilang maha; (19.8 - 160 Lakh)

# %%
# Cek Outlier Kilometers Driven
df_outliers_km = Cek_Outliers(df,'Kilometers_Driven')
df_outliers_km
# Out:
#                                         Name    Location  Year  \
# ID
# 29       Toyota Innova 2.5 V Diesel 7-seater      Mumbai  2007
# 64                        Tata Indica V2 eLS     Chennai  2016
# 77                      Toyota Innova 2.0 G1     Chennai  2006
# 154      Skoda Superb Elegance 2.0 TDI CR AT        Pune  2012
# 164        Ford Ecosport 1.5 DV5 MT Ambiente       Kochi  2014
# ...                                      ...         ...   ...
# 5852    Toyota Innova 2.5 G4 Diesel 8-seater     Chennai  2008
# 5871  Ford Endeavour 4x2 XLT Limited Edition        Pune  2009
# 5914          Skoda Octavia Elegance 1.9 TDI   Hyderabad  2003
# 5953                    Ford Figo Diesel EXI      Jaipur  2012
# 5957                      Honda City 1.5 EXI  Coimbatore  2004
#
#       Kilometers_Driven Fuel_Type Transmission  Engine_CC  Power_bhp  Price  \
# ID
# 29               262000    Diesel       Manual     2494.0     102.00   4.00
# ...

# %%
# Mencetak baris data kendaraan dengan jarak tempuh tertinggi pada outliers
df_outliers_km.max()
# Out:
# Name                 Volvo XC60 D5
# Location                      Pune
# Year                          2017
# Kilometers_Driven          6500000
# Fuel_Type                   Petrol
# Transmission                Manual
# Engine_CC                   3200.0
# Power_bhp                    282.0
# Price                         65.0
# Age                             23
# dtype: object

# %%
# Mencetak baris data kendaraan dengan harga terendaah pada outliers
df_outliers_km.min()
# Out:
# Name                 Audi A6 2011-2015 2.0 TDI Premium Plus
# Location                                          Ahmedabad
# Year                                                   1999
# Kilometers_Driven                                    131765
# Fuel_Type                                            Diesel
# Transmission                                      Automatic
# Engine_CC                                             796.0
# Power_bhp                                              37.0
# Price                                                   0.7
# Age                                                       5
# dtype: object

# %%
# Mencetak diagram kotak garis dengan 'Kilometers_Driven' sebagai sumbu x nya
sns.boxplot(data=df, x='Kilometers_Driven')
plt.show()

# %% [markdown]
# Data pada kolom *Kilometers Driven* yang termasuk dalam outlier merupakan kendaraan yang memiliki jarak tempuh yang jauh di atas rata - rata (131.765 - 6.500.000 Km)

# %% [markdown]
# # Goals
# **Meningkatkan Penjualan pada Quartal 4 Tahun 2022**

# %% [markdown]
# "Passenger vehicle sales declined 10.7% in January 2022 against the year-ago period as the shortage of semiconductors continued to create supply shortages, said the Federation of Automobile Dealers Associations (FADA)"
#
# "However, on the positive side, used car sellers across markets, including India, are enjoying a boom in demand. Prices of used cars rose by about 20% globally on an annual basis through August 2021"
#
# "India's used car market was valued at 27 billion dollars in 2020, and it is expected to reach 50 billion dollars by 2026"
#
# Sumber:
# http://timesofindia.indiatimes.com/articleshow/89446943.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst"

# %% [markdown]
# # Assumption
# * Data merupakan data penjualan kendaraan pada 11 kota di India dimulai dari Quartal 1 hingga Quartal 3 tahun 2022

# %% [markdown]
# # Business Question
#
# 1. Pada kota apa di india yang dapat mencetak penjualan tertinggi juga terendah
# 2. Apakah usia kendaraan mempengaruhi banyaknya penjualan kendaraan
# 3. Apakah jenis bahan bakar pada kota kendaraan berada mempengaruhi besarnya penjualan kendaraan
# 4. Apakah jenis bahan bakar kendaraan mempengaruhi reliabilitas kendaraan bagi pembeli
# 5. Apakah transmisi mempengaruhi keputusan calon pembeli dalam memilih kendaraan pada daerah mereka

# %%
# Membuat kolom baru berisi informasi usia tiap kendaraan
df['Age'] = df.apply(lambda x: 2022 - x['Year'], axis=1)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# ### Assumption
# * Seluruh penjualan terjadi pada tahun 2022

# %%
# Membuat kolom baru berisi informasi 'Pajak Jalan' tiap kendaraan
df['Road_tax'] = df.apply(lambda x: '75%' if x['Age'] == 4 else ('25%' if x['Age'] > 15 else '0%'), axis=1)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# kolom 'Road_tax' diisi sesusai ketentuan dimana kendaraan dengan usia lebih dari 4 tahun namun kurang dari 5 tahun dikenakan pajak 75% dari biaya pembuatan kendaraan dan 25% untuk usia lebih dari 15%

# %% [markdown]
# ![Screenshot_2.png](attachment:f7855cd5-3195-4567-91c4-cc7e076b65f3.png)
#
# Sumber: https://www.bankbazaar.com/driving-licence/rules-regulations-of-road-tax-india.html

# %% [markdown]
# ### Assumption
# * Kendaraan yang dibeli akan digunakan pada daerah yang sama dengan lokasi pembelian

# %%
# Membuat def fungsi memberikan nilai harga bahan bakar sesuai dengan jenis bahan bakar dan lokasi kendaraan
def fuel_price(x):
    if x['Location'] == 'Ahmedabad' and x['Fuel_Type'] == 'Petrol' :
        return 96.42
    elif x['Location'] == 'Ahmedabad' and x['Fuel_Type'] == 'Diesel' :
        return 92.17
    elif x['Location'] == 'Bangalore' and x['Fuel_Type'] == 'Petrol' :
        return 101.94
    elif x['Location'] == 'Bangalore' and x['Fuel_Type'] == 'Diesel' :
        return 87.89
    elif x['Location'] == 'Chennai' and ['Fuel_Type'] == 'Petrol' :
        return 102.63
    elif x['Location'] == 'Chennai'and x['Fuel_Type'] == 'Diesel' :
        return 94.24
    elif x['Location'] == 'Coimbatandre' and x['Fuel_Type'] == 'Petrol' :
        return 103.11
    elif x['Location'] == 'Coimbatore'and x['Fuel_Type'] == 'Diesel' :
        return 94.73
    elif x['Location'] == 'Delhi' and x['Fuel_Type'] == 'Petrol' :
        return 96.72
    elif x['Location'] == 'Delhi' and x['Fuel_Type'] == 'Diesel' :
        return 89.62
    elif x['Location'] == 'Hyderabad' and x['Fuel_Type'] == 'Petrol' :
        return 109.66
    elif x['Location'] == 'Hyderabad' and  x['Fuel_Type'] == 'Diesel' :
        return 97.82
    elif x['Location'] == 'Jaipur' and x['Fuel_Type'] == 'Petrol' :
        return 108.48
    elif x['Location'] == 'Jaipur' and x['Fuel_Type'] == 'Diesel' :
        return 93.72
    elif x['Location'] == 'Kochi' and x['Fuel_Type'] == 'Petrol' :
        return 96.62
    elif x['Location'] == 'Kochi' and x['Fuel_Type'] == 'Diesel' :
        return 89.45
    elif x['Location'] == 'Kolkata' and x['Fuel_Type'] == 'Petrol' :
        return 106.03
    elif x['Location'] == 'Kolkata' and x['Fuel_Type'] == 'Diesel' :
        return 92.76
    elif x['Location'] == 'Mumbai' and x['Fuel_Type'] == 'Petrol' :
        return 111.35
    elif x['Location'] == 'Mumbai' and x['Fuel_Type'] == 'Diesel' :
        return 97.28
    elif x['Location'] == 'Pune' and x['Fuel_Type'] == 'Petrol' :
        return 110.88
    elif x['Fuel_Type'] == 'Electric' :
        return 6.2
    else:
        return 95.37

# %%
# Menambahkan kolom yang berisi informasi harga bahan bakar baik diesel maupun bensin pada daerah dimana kendaraan tersebut berada
df['Fuel_Price'] = df.apply(fuel_price, axis=1)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# ID
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# ![Screenshot_3.png](attachment:17c2fd4c-318d-4496-b0da-6be74e400fa8.png)
#
# Source: https://www.goodreturns.in/petrol-price.html#Daily+Petrol+Prices+Revision+in+India

# %% [markdown]
# "OERC secretary Priyabrat Patnaik said the existing retail electricity tariff of ₹3 per unit for the first 50 units, ₹4.80 for 50-200 units, ₹5.80 for 200-400 units, ₹6.20 for above 400 units will continue for 2022-23."
# Sumber: https://www.hindustantimes.com/business/no-increase-in-tariff-for-2022-23-says-odisha-power-regulator-after-2-back-to-back-hikes-101648151716287.html

# %% [markdown]
# ## 1. Pada kota apa di india yang dapat mencetak penjualan tertinggi juga terendah

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan lokasi dari masing masing kendaraan dan di sortir dari yang terbanyak
Location2_count = df['Name'].groupby(df['Location']).count()
df6 = Location2_count.to_frame(name="Jumlah Kendaraan")
df6.sort_values(by = 'Jumlah Kendaraan', ascending=False)
# Out:
#             Jumlah Kendaraan
# Location
# Mumbai                   772
# Hyderabad                733
# Kochi                    643
# Coimbatore               636
# Pune                     608
# Delhi                    544
# Kolkata                  535
# Chennai                  492
# Jaipur                   411
# Bangalore                358
# Ahmedabad                221

# %%
# Mencetak rerata jumlah penjualan kendaraan dari seluruh daerah
df6.mean()
# Out:
# Jumlah Kendaraan    541.181818
# dtype: float64

# %% [markdown]
# * Rata-rata penjualan kendaraan pada Q1 hingga Q3 adalah 541 kendaraan

# %% [markdown]
# "Sebelumnya bernama Bombay (sampai tahun 1995) masuk ke jajaran sebagai kota terpadat di India dan kota terpadat di dunia. Populasi penduduk di kota ini mencapai 18,4 juta jiwa."
#
# Sumber: https://ilmugeografi.com/ilmu-sosial/kota-terpadat-di-india

# %% [markdown]
# ## INSIGHT
# 1. Mumbai menjadi daerah dengan tingkat penjualan tertinggi pada 3 Quartal pertama pada tahun 2022
# 2. Terdapat 5 kota yang jumlah penjualannya dibawah jumlah penjualan rata-rata kendaraan -> Kolkata, Chennai, Jaipur, Bangalore, Ahmedabad.
# 3. Ahmedabad menjadi kota dengan rata-rata penjualan kendaraan terendah.
#
# ## ASUMSI
# 1. India menjadi Kota dengan populasi paling tinggi di India
# 2. Masyarakat Ahmedabad tidak terlalu menyukai "Used Car" karena masyarakat memiliki tingkat ekonomi yang lebih tinggi dari daerah lainnya.

# %% [markdown]
# "Ahmedabad is also one of the richest cities in India with an estimated GDP of $68 billion. Known as the 'Manchester of the East'"<br>
# source : https://traveltriangle.com/blog/richest-cities-in-india/

# %% [markdown]
# ## 2. Apakah usia kendaraan mempengaruhi banyaknya penjualan kendaraan

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan usia dan Road tax dari masing masing kendaraan
df4 = pd.crosstab(index =[df['Road_tax'], df['Age']], columns = 'Jumlah Kendaraan',
            values = df['Name'], aggfunc='count',
           colnames= [''])
df4
# Out:
#               Jumlah Kendaraan
# Road_tax Age
# 0%       3                 101
#          5                 582
#          6                 737
#          7                 735
#          8                 785
#          9                 640
#          10                569
#          11                464
#          12                337
#          13                198
#          14                172
#          15                124
# 25%      16                 78
#          17                 56
#          18                 31
#          19                 17
#          20                 15
#          21                  8
#          22                  4
#          23                  2
#          24                  4
# 75%      4                 294

# %%
# Mencetak rerata jumlah kendaraan terjual yang telah dikelompokan dengan usia dan Road tax kendaraan
df4['Jumlah Kendaraan'].mean()
# Out:
# 270.59090909090907

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan Road tax dari masing masing kendaraan
pd.crosstab(index =df['Road_tax'], columns = 'Jumlah Kendaraan',
        values = df['Name'], aggfunc='count',
        colnames= ['']).sort_values(by='Jumlah Kendaraan', ascending=False)
# Out:
#           Jumlah Kendaraan
# Road_tax
# 0%                    5444
# 75%                    294
# 25%                    215

# %% [markdown]
# * Rata-rata penjualan kendaraan pada 3 kuartal pertama berdasarkan usia adalah 271

# %% [markdown]
# ![Screenshot_2.png](attachment:f7855cd5-3195-4567-91c4-cc7e076b65f3.png)
#
# Sumber: https://www.bankbazaar.com/driving-licence/rules-regulations-of-road-tax-india.html

# %% [markdown]
# ## INSIGHT
# 1. Dari tabel, terlihat jelas bahwa semakin tua umur kendaraan maka harga kendaraan akan semakin murah
# 2. Dari tabel, Rentang usia kendaraan yang paling banyak diminati adalah usia 4-12 tahun.
# 3. Dari tabel, Penjualan kendaraan dengan usia diatas 15 tahun sangat jauh dari rata-rata keseluruhan penjualan kendaraan.
#
# ## ASUMSI
# 1. Kendaraan dengan usia 3 tahun mengalami jumlah penjualan dibawah rata-rata dikarenakan harga kendaraan yang jauh lebih tinggi.
# 2. Hasil Penjualan dengan road tax 75% masih digemari karena usia kendaraan yang masih relatif baru.

# %% [markdown]
# ## 3. Apakah jenis bahan bakar pada kota kendaraan berada mempengaruhi besarnya penjualan kendaraan

# %%
# Mencetak dataframe berisi harga bahan bakar yang dikelompokan dengan jenis bahan bakar dan lokasi dari masing masing kendaraan
Fuel_Prc = pd.crosstab(index =[df['Location'], df['Fuel_Type']], columns = 'Harga Bahan Bakar',
                        values = df['Fuel_Price'], aggfunc='median',
                        colnames= [''])
Fuel_Prc
# Out:
#                       Harga Bahan Bakar
# Location   Fuel_Type
# Ahmedabad  Diesel                 92.17
#            Petrol                 96.42
# Bangalore  Diesel                 87.89
#            Petrol                101.94
# Chennai    Diesel                 94.24
#            Electric                6.20
#            Petrol                 95.37
# Coimbatore Diesel                 94.73
#            Petrol                 95.37
# Delhi      Diesel                 89.62
#            Petrol                 96.72
# Hyderabad  Diesel                 97.82
#            Petrol                109.66
# Jaipur     Diesel                 93.72
#            Petrol                108.48
# Kochi      Diesel                 89.45
#            Petrol                 96.62
# Kolkata    Diesel                 92.76
#            Petrol                106.03
# Mumbai     Diesel                 97.28
#            Electric                6.20
#            Petrol                111.35
# ...

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan jenis bahan bakar dan lokasi dari masing masing kendaraan
Fuel_Cnt = pd.crosstab(index =[df['Location'], df['Fuel_Type']], columns = 'Jumlah Kendaraan',
                       values = df['Name'], aggfunc='count',
                       colnames= [''])
Fuel_Cnt
# Out:
#                       Jumlah Kendaraan
# Location   Fuel_Type
# Ahmedabad  Diesel                  138
#            Petrol                   83
# Bangalore  Diesel                  219
#            Petrol                  139
# Chennai    Diesel                  289
#            Electric                  1
#            Petrol                  202
# Coimbatore Diesel                  356
#            Petrol                  280
# Delhi      Diesel                  306
#            Petrol                  238
# Hyderabad  Diesel                  506
#            Petrol                  227
# Jaipur     Diesel                  230
#            Petrol                  181
# Kochi      Diesel                  304
#            Petrol                  339
# Kolkata    Diesel                  256
#            Petrol                  279
# Mumbai     Diesel                  313
#            Electric                  1
#            Petrol                  458
# ...

# %%
# Menambahkan kolom 'jumlah kendaraan' pada dataframe Fuel_Prc dari Fuel_Cnt
Fuel_Prc['Jumlah Kendaraan'] = Fuel_Cnt
Fuel_Prc
# Out:
#                       Harga Bahan Bakar  Jumlah Kendaraan
# Location   Fuel_Type
# Ahmedabad  Diesel                 92.17               138
#            Petrol                 96.42                83
# Bangalore  Diesel                 87.89               219
#            Petrol                101.94               139
# Chennai    Diesel                 94.24               289
#            Electric                6.20                 1
#            Petrol                 95.37               202
# Coimbatore Diesel                 94.73               356
#            Petrol                 95.37               280
# Delhi      Diesel                 89.62               306
#            Petrol                 96.72               238
# Hyderabad  Diesel                 97.82               506
#            Petrol                109.66               227
# Jaipur     Diesel                 93.72               230
#            Petrol                108.48               181
# ...

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan jenis bahan bakar dan lokasi dari masing masing kendaraan
Price2_mean = pd.crosstab(index =[df['Location'], df['Fuel_Type']], columns = 'Rerata Harga',
                       values = df['Price'], aggfunc='mean',
                       colnames= [''])
Price2_mean
# Out:
#                       Rerata Harga
# Location   Fuel_Type
# Ahmedabad  Diesel        10.859420
#            Petrol         4.660482
# Bangalore  Diesel        17.245388
#            Petrol         7.157626
# Chennai    Diesel        10.413080
#            Electric      13.000000
#            Petrol         3.958960
# Coimbatore Diesel        20.747275
#            Petrol         7.870429
# Delhi      Diesel        12.554510
#            Petrol         6.328992
# Hyderabad  Diesel        11.955731
#            Petrol         5.202643
# Jaipur     Diesel         7.964304
#            Petrol         3.106630
# Kochi      Diesel        15.515888
#            Petrol         7.452714
# Kolkata    Diesel         6.773594
#            Petrol         4.640538
# Mumbai     Diesel        14.288626
#            Electric      12.750000
#            Petrol         6.315764
# Pune       Diesel         9.851076
#            Petrol         4.083312

# %%
Fuel_Prc['Rerata Harga'] = Price2_mean
Fuel_Prc
# Out:
#                       Harga Bahan Bakar  Jumlah Kendaraan  Rerata Harga
# Location   Fuel_Type
# Ahmedabad  Diesel                 92.17               138     10.859420
#            Petrol                 96.42                83      4.660482
# Bangalore  Diesel                 87.89               219     17.245388
#            Petrol                101.94               139      7.157626
# Chennai    Diesel                 94.24               289     10.413080
#            Electric                6.20                 1     13.000000
#            Petrol                 95.37               202      3.958960
# Coimbatore Diesel                 94.73               356     20.747275
#            Petrol                 95.37               280      7.870429
# Delhi      Diesel                 89.62               306     12.554510
#            Petrol                 96.72               238      6.328992
# Hyderabad  Diesel                 97.82               506     11.955731
# ...

# %%
# Membuat list berisi rerata harga bahan bakar yang dikelompokan dengan masing - masing lokasi dari kendaraan
Fuel_mean = df['Fuel_Price'].groupby(df['Location']).mean()
Fuel_mean
# Merubah list sebelumnya menjadi dataframe dengan nama kolom 'Rerata Harga Bahan Bakar'
df2 = Fuel_mean.to_frame(name='Rerata Harga Bahan Bakar')
df2
# Membuat list berisi jumlah kendaraan terjual yang dikelompokan dengan masing - masing lokasi dari kendaraan
Location_count = df['Name'].groupby(df['Location']).count()
Price_mean = df['Name'].groupby(df['Location']).count()
# Menambahkan kolom 'jumlah kendaraan' pada dataframe df2 dari Fuel_mean
df2['Jumlah Kendaraan'] = Location_count
df2
# Out:
#             Rerata Harga Bahan Bakar  Jumlah Kendaraan
# Location
# Ahmedabad                  93.766154               221
# Bangalore                  93.345168               358
# Chennai                    94.525000               492
# Coimbatore                 95.011761               636
# Delhi                      92.726250               544
# Hyderabad                 101.486685               733
# Jaipur                    100.220146               411
# Kochi                      93.230140               643
# Kolkata                    99.680243               535
# Mumbai                    105.509249               772
# Pune                      103.533158               608

# %%
# Mencetak grafik pencar dimana kolom 'Harga Bahan Bakar' sebagai sumbu x dan kolom 'Jumlah Kendaraan' pada sumbu y
sns.scatterplot(x = Fuel_Prc['Harga Bahan Bakar'], y = Fuel_Prc['Jumlah Kendaraan'])
plt.show()

# %%
# Karena tidak linear maka spearman merupakan method yang tepat
Fuel_Prc[['Harga Bahan Bakar','Jumlah Kendaraan']].corr(method='spearman')
# Out:
#                    Harga Bahan Bakar  Jumlah Kendaraan
#
# Harga Bahan Bakar           1.000000          0.347845
# Jumlah Kendaraan            0.347845          1.000000

# %% [markdown]
# Uji korelasi Spearman antara variabel **Harga Bahan Bakar** dengan **Jumlah Kendaraan** adalah 0.347845 positif. Artinya, sifat hubungan keduanya searah, namun kekuatan hubungannya lemah.

# %%
# Mencetak grafik pencar dimana kolom 'Harga Bahan Bakar' sebagai sumbu x dan kolom 'Jumlah Kendaraan' pada sumbu y
sns.scatterplot(x = Fuel_Prc['Harga Bahan Bakar'], y = Fuel_Prc['Rerata Harga'])
plt.show()

# %%
# Karena tidak linear maka spearman merupakan method yang tepat
Fuel_Prc[['Harga Bahan Bakar','Rerata Harga']].corr(method='spearman')
# Out:
#                    Harga Bahan Bakar  Rerata Harga
#
# Harga Bahan Bakar           1.000000     -0.682917
# Rerata Harga               -0.682917      1.000000

# %% [markdown]
# Uji korelasi Spearman antara variabel **Harga Bahan Bakar** dengan **Jumlah Kendaraan** adalah 0.682917 negatif. Artinya, sifat hubungan keduanya berlawanan, namun kekuatan hubungannya sedang.

# %% [markdown]
# ## INSIGHT
# 1. Mayoritas kota di India memilih jenis Kendaraan dengan bahan bakar Diesel, selain kota Kochi, Kolkata, Mumbai, Pune.
# 2. Tingginya rerata harga kendaraan diesel tidak mempengaruhi antusias konsumen dalam memilih kendaraan berbahan bakar diesel ketimbang petrol dan electric
#
# ## ASUMSI
# 1. Setiap daerah belum mempunyai akses yang memadai untuk mendukung jenis kendaraan dengan bahan bakar elektrik
# 3. Daerah dengan moyoritas kendaraan dengan bahan bakar Petrol, lebih aware terhadap emisi karbon

# %% [markdown]
# ## 4. Apakah jenis bahan bakar kendaraan mempengaruhi reliabilitas kendaraan bagi pembeli

# %%
# Membuat list berisi rerata jarak tempuh kendaraan yang dikelompokan dengan masing - masing jenis bahan bakar dari kendaraan
km_mean = df['Kilometers_Driven'].groupby(df['Fuel_Type']).mean()
km_mean
# Merubah list sebelumnya menjadi dataframe dengan nama kolom 'Rata-rata Kilometer berjalan'
df3 = km_mean.to_frame(name="Rata-rata Kilometer berjalan")
# Membuat list berisi jumlah kendaraan terjual yang dikelompokan dengan masing - masing jenis bahan bakar dari kendaraan
name_count= df['Name'].groupby(df['Fuel_Type']).count()
# Menambahkan kolom 'jumlah kendaraan' pada dataframe df3 dari name_count
df3['Jumlah Kendaraan'] = name_count
df3.sort_values(by = 'Rata-rata Kilometer berjalan', ascending =False)
# Out:
#            Rata-rata Kilometer berjalan  Jumlah Kendaraan
# Fuel_Type
# Diesel                     67669.459906              3205
# Petrol                     48385.670430              2746
# Electric                   47000.000000                 2

# %% [markdown]
# ## INSIGHT
# 1. Dari tabel, Masyarakat sangat menyukai jenis kendaraan yang menggunakan bahan bakar jenis Diesel
# 2. Dari tabel, Kendaraan dengan jenis bahan bakar diesel juga lebih sering digunakan karena memiliki rata-rata kilometer berjalan yang lebih tinggi dibanding kendaraan dengan 2 jenis bahan bakar lainnya.
# 3. Dari tabel, rata-rata kilometer berjalan kendaraan dengan jenis bahan bakar petrol dan elektrik tidak jauh berbeda.

# %% [markdown]
# ## 5. Apakah transmisi mempengaruhi keputusan calon pembeli dalam memilih kendaraan pada daerah mereka

# %%
# Mencetak dataframe berisi jumlah kendaraan terjual yang dikelompokan dengan lokasi dan jenis transmisi dari masing masing kendaraan
df7 = pd.crosstab(index =[df['Location'], df['Transmission']], columns = 'Jumlah Kendaraan',
            values = df['Name'], aggfunc='count',
           colnames= [''])
df7
# Out:
#                          Jumlah Kendaraan
# Location   Transmission
# Ahmedabad  Automatic                   58
#            Manual                     163
# Bangalore  Automatic                  144
#            Manual                     214
# Chennai    Automatic                  120
#            Manual                     372
# Coimbatore Automatic                  247
#            Manual                     389
# Delhi      Automatic                  171
#            Manual                     373
# Hyderabad  Automatic                  196
#            Manual                     537
# Jaipur     Automatic                   52
#            Manual                     359
# Kochi      Automatic                  205
#            Manual                     438
# Kolkata    Automatic                   80
#            Manual                     455
# Mumbai     Automatic                  303
#            Manual                     469
# Pune       Automatic                  144
# ...

# %%
Price3_mean = pd.crosstab(index =[df['Location'], df['Transmission']], columns = 'Rerata Harga',
                       values = df['Price'], aggfunc='mean',
                       colnames= [''])
Price3_mean
# Out:
#                          Rerata Harga
# Location   Transmission
# Ahmedabad  Automatic        16.837586
#            Manual            5.575706
# Bangalore  Automatic        24.237500
#            Manual            5.988084
# Chennai    Automatic        17.372667
#            Manual            4.670349
# Coimbatore Automatic        26.647611
#            Manual            7.732108
# Delhi      Automatic        20.026725
#            Manual            5.156595
# Hyderabad  Automatic        21.284439
#            Manual            5.696182
# Jaipur     Automatic        14.351923
#            Manual            4.589944
# Kochi      Automatic        21.782488
#            Manual            6.342215
# Kolkata    Automatic        15.505500
#            Manual            3.930352
# Mumbai     Automatic        16.042442
#            Manual            5.366418
# Pune       Automatic        14.505833
#            Manual            4.428728

# %%
df7['Rerata Harga'] = Price3_mean
df7
# Out:
#                          Jumlah Kendaraan  Rerata Harga
# Location   Transmission
# Ahmedabad  Automatic                   58     16.837586
#            Manual                     163      5.575706
# Bangalore  Automatic                  144     24.237500
#            Manual                     214      5.988084
# Chennai    Automatic                  120     17.372667
#            Manual                     372      4.670349
# Coimbatore Automatic                  247     26.647611
#            Manual                     389      7.732108
# Delhi      Automatic                  171     20.026725
#            Manual                     373      5.156595
# Hyderabad  Automatic                  196     21.284439
#            Manual                     537      5.696182
# Jaipur     Automatic                   52     14.351923
#            Manual                     359      4.589944
# Kochi      Automatic                  205     21.782488
# ...

# %% [markdown]
# ## INSIGHT
# 1. Dari tabel, Kendaraan dengan transmisi Manual memiliki jumlah penjualan yang lebih banyak dibandingkan kendaraan dengan transmisi Automatic di setiap daerah yang di karenakan oleh tingginya rerata harga kendaraan dengan transmisi automatic
# 2. Dari Tabel, Penjulan kendaraan dengan transmisi Automatic paling banyak terjadi di Mumbai

# %% [markdown]
# ## KESIMPULAN
# 1. Kendaraan yang paling banyak diminati :
#     * Kendaraan dengan rentang usia 4-12 tahun
#     * Kendraan dengan rate tax 0%
#     * Kendaraan yang menggunakan bahan bakar Diesel
#     * Kendaraan yang menggunakan transmisi Automatic

# %% [markdown]
# ### REKOMENDASI
# 1. Memperbanyak Stock Kendaraan pada daerah yang penjualannya di atas rata-rata (Mumbai, Hyderabad, Kochi, Coimbatore, Pune, Delhi)
# 2. Menaikkan brand awareness pada daerah dengan tingkat penjualannya dibawah rata-rata
# 3. Meningkatkan stock kendaraan dengan usia 4-12 tahun dan mengurangi kendaraan dengan usia di atas 15 tahun
# 4. Membuka market pasar baru pengadaan charging station dengan urutan prioritas dengan daerah yang penjualannya di atas rata-rata.
# 5. Menaikkan brand awareness bahwa kendaraan dengan bahan bakar elektric memiliki rata-rata jarak tempuh yang sama dengan bahan bakar lain, dan    memiliki harga lebih murah.
#
#
# * Pros :<br>
# Dengan berfokus pada tipe kendaraan yang disukai masyarakat akan meningkatkan tingkat penjualan kendaraan
# Proses seleksi mobil untuk dibeli dapat lebih mudah dan efektif karena adanya guide line pembelian
# * Cons :<br>
# Berfokus kepada hal yang disukai oleh masyarakat akan mengurai pilihan ataupun keberagaman jenis mobil yang di jual.
